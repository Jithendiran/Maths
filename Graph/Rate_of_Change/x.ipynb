# %% [markdown]
# # Horizontal Expansion
#
# $$\frac{\Delta x}{\Delta y} = \text{ Constant Rate of }\Delta x \text{ for single unit of }\Delta y$$
#
# x denotes left or right, horizontal line, (x-axis)
#
# y denotes up or down, vertical line, (y-axis)
#
# What we find here is for every 1 unit of y value, how much left or right the x value is
#
# **Horizontal Expansion** is a term describes how the surface is expanded
#
# **Horizontal Expansion** or **Invert Slope**
#
# $$\text{ Invert Slope } = \frac{x2 - x1}{ y2 - y1} = \frac{\Delta x}{ \Delta y}$$
#
# In algebra Invert Slope is denoted in $\frac{1}{m}$
#
# if the horizontal line is small, line is very steep
#
# if horizontal line very long, very little steep

# %% [markdown]
# ### Quad 1
#
# | # | Slope ($m$) | $\Delta x / \Delta y$ Target | P1 $(x_1, y_1)$ | P2 $(x_2, y_2)$ | $\Delta x$ | $\Delta y$ | $\frac{1}{m} = \frac{\Delta x}{\Delta y}$ | Interpretation of $\frac{1}{m}$ ($\Delta y=1$) |
# | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | 1 | $\mathbf{m = \infty}$ | $\frac{0}{\pm}$ | $(2, 1)$ | $(2, 3)$ | $0$ | $2$ | $\mathbf{0}$ | $\mathbf{0}$ units Right (Vertical Line) |
# | 2 | $\mathbf{m = 2}$ | $\frac{1}{2}$ | $(1, 1)$ | $(2, 3)$ | $1$ | $2$ | $\mathbf{0.5}$ | $\mathbf{0.5}$ units Right (Steep) |
# | 3 | $\mathbf{m = 1}$ | $\frac{1}{1}$ | $(1, 1)$ | $(2, 2)$ | $1$ | $1$ | $\mathbf{1}$ | $\mathbf{1}$ unit Right (Moderate) |
# | 4 | $\mathbf{m = 0.5}$ | $\frac{2}{1}$ | $(1, 1)$ | $(3, 2)$ | $2$ | $1$ | $\mathbf{2}$ | $\mathbf{2}$ units Right (Shallow) |
# | 5 | $\mathbf{m = 0}$ | $\frac{\pm}{0}$ | $(1, 2)$ | $(3, 2)$ | $2$ | $0$ | **$\infty$ (Undefined)** | Infinite Run (Horizontal Line) |
# | 6 | $\mathbf{m = -2}$ | $\frac{1}{-2}$ | $(3, 3)$ | $(4, 1)$ | $1$ | $-2$ | $\mathbf{-0.5}$ | For 1 unit $\mathbf{down}$, $\mathbf{0.5}$ units $\mathbf{right}$ (Steep Fall) |
# | 7 | $\mathbf{m = -1}$ | $\frac{1}{-1}$ | $(3, 3)$ | $(4, 2)$ | $1$ | $-1$ | $\mathbf{-1}$ | For 1 unit $\mathbf{down}$, $\mathbf{1}$ unit $\mathbf{right}$ (Moderate Fall) |
# | 8 | $\mathbf{m = -0.5}$ | $\frac{2}{-1}$ | $(3, 3)$ | $(5, 2)$ | $2$ | $-1$ | $\mathbf{-2}$ | For 1 unit $\mathbf{down}$, $\mathbf{2}$ units $\mathbf{right}$ (Shallow Fall) |
# | 9 | $\mathbf{m = \frac{1}{-3}}$ | $\frac{-3}{1}$ | $(4, 4)$ | $(1, 5)$ | $-3$ | $1$ | $\mathbf{-3}$ | For 1 unit $\mathbf{up}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |
# | 10 | $\mathbf{m = \frac{1}{3}}$ | $\frac{3}{1}$ | $(4, 4)$ | $(1, 3)$ | $-3$ | $-1$ | $\mathbf{3}$ | For 1 unit $\mathbf{down}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |

# %% [markdown]
# ### Quad II
#
# | # | Slope ($m$) | $\Delta x / \Delta y$ Target | P1 $(x_1, y_1)$ | P2 $(x_2, y_2)$ | $\Delta x$ | $\Delta y$ | $\frac{1}{m} = \frac{\Delta x}{\Delta y}$ | Interpretation of $\frac{1}{m}$ ($\Delta y=1$) |
# | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | 1 | $\mathbf{m = \infty}$ | $\frac{0}{\pm}$ | $(-2, 1)$ | $(-2, 3)$ | $0$ | $2$ | $\mathbf{0}$ | $\mathbf{0}$ units Right (Vertical Line) |
# | 2 | $\mathbf{m = 2}$ | $\frac{1}{2}$ | $(-3, 1)$ | $(-2, 3)$ | $1$ | $2$ | $\mathbf{0.5}$ | $\mathbf{0.5}$ units Right (Steep) |
# | 3 | $\mathbf{m = 1}$ | $\frac{1}{1}$ | $(-2, 1)$ | $(-1, 2)$ | $1$ | $1$ | $\mathbf{1}$ | $\mathbf{1}$ unit Right (Moderate) |
# | 4 | $\mathbf{m = 0.5}$ | $\frac{2}{1}$ | $(-3, 1)$ | $(-1, 2)$ | $2$ | $1$ | $\mathbf{2}$ | $\mathbf{2}$ units Right (Shallow) |
# | 5 | $\mathbf{m = 0}$ | $\frac{\pm}{0}$ | $(-3, 2)$ | $(-1, 2)$ | $2$ | $0$ | **$\infty$ (Undefined)** | Infinite Run (Horizontal Line) |
# | 6 | $\mathbf{m = -2}$ | $\frac{1}{-2}$ | $(-1, 3)$ | $(0, 1)$ | $1$ | $-2$ | $\mathbf{-0.5}$ | For 1 unit $\mathbf{down}$, $\mathbf{0.5}$ units $\mathbf{right}$ (Steep Fall) |
# | 7 | $\mathbf{m = -1}$ | $\frac{1}{-1}$ | $(-1, 3)$ | $(0, 2)$ | $1$ | $-1$ | $\mathbf{-1}$ | For 1 unit $\mathbf{down}$, $\mathbf{1}$ unit $\mathbf{right}$ (Moderate Fall) |
# | 8 | $\mathbf{m = -0.5}$ | $\frac{2}{-1}$ | $(-1, 3)$ | $(1, 2)$ | $2$ | $-1$ | $\mathbf{-2}$ | For 1 unit $\mathbf{down}$, $\mathbf{2}$ units $\mathbf{right}$ (Shallow Fall) |
# | 9 | $\mathbf{m = \frac{1}{-3}}$ | $\frac{-3}{1}$ | $(-1, 4)$ | $(-4, 5)$ | $-3$ | $1$ | $\mathbf{-3}$ | For 1 unit $\mathbf{up}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |
# | 10 | $\mathbf{m = \frac{1}{3}}$ | $\frac{3}{1}$ | $(-1, 4)$ | $(-4, 3)$ | $-3$ | $-1$ | $\mathbf{3}$ | For 1 unit $\mathbf{down}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |

# %% [markdown]
# ### Quad III
#
# | # | Slope ($m$) | $\Delta x / \Delta y$ Target | P1 $(x_1, y_1)$ | P2 $(x_2, y_2)$ | $\Delta x$ | $\Delta y$ | $\frac{1}{m} = \frac{\Delta x}{\Delta y}$ | Interpretation of $\frac{1}{m}$ ($\Delta y=1$) |
# | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | 1 | $\mathbf{m = \infty}$ | $\frac{0}{\pm}$ | $(-2, -3)$ | $(-2, -1)$ | $0$ | $2$ | $\mathbf{0}$ | $\mathbf{0}$ units Right (Vertical Line) |
# | 2 | $\mathbf{m = 2}$ | $\frac{1}{2}$ | $(-3, -3)$ | $(-2, -1)$ | $1$ | $2$ | $\mathbf{0.5}$ | $\mathbf{0.5}$ units Right (Steep) |
# | 3 | $\mathbf{m = 1}$ | $\frac{1}{1}$ | $(-2, -2)$ | $(-1, -1)$ | $1$ | $1$ | $\mathbf{1}$ | $\mathbf{1}$ unit Right (Moderate) |
# | 4 | $\mathbf{m = 0.5}$ | $\frac{2}{1}$ | $(-3, -2)$ | $(-1, -1)$ | $2$ | $1$ | $\mathbf{2}$ | $\mathbf{2}$ units Right (Shallow) |
# | 5 | $\mathbf{m = 0}$ | $\frac{\pm}{0}$ | $(-3, -2)$ | $(-1, -2)$ | $2$ | $0$ | **$\infty$ (Undefined)** | Infinite Run (Horizontal Line) |
# | 6 | $\mathbf{m = -2}$ | $\frac{1}{-2}$ | $(-1, -1)$ | $(0, -3)$ | $1$ | $-2$ | $\mathbf{-0.5}$ | For 1 unit $\mathbf{down}$, $\mathbf{0.5}$ units $\mathbf{right}$ (Steep Fall) |
# | 7 | $\mathbf{m = -1}$ | $\frac{1}{-1}$ | $(-1, -1)$ | $(0, -2)$ | $1$ | $-1$ | $\mathbf{-1}$ | For 1 unit $\mathbf{down}$, $\mathbf{1}$ unit $\mathbf{right}$ (Moderate Fall) |
# | 8 | $\mathbf{m = -0.5}$ | $\frac{2}{-1}$ | $(-1, -1)$ | $(1, -2)$ | $2$ | $-1$ | $\mathbf{-2}$ | For 1 unit $\mathbf{down}$, $\mathbf{2}$ units $\mathbf{right}$ (Shallow Fall) |
# | 9 | $\mathbf{m = \frac{1}{-3}}$ | $\frac{-3}{1}$ | $(-1, -1)$ | $(-4, 0)$ | $-3$ | $1$ | $\mathbf{-3}$ | For 1 unit $\mathbf{up}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |
# | 10 | $\mathbf{m = \frac{1}{3}}$ | $\frac{3}{1}$ | $(-1, -1)$ | $(-4, -2)$ | $-3$ | $-1$ | $\mathbf{3}$ | For 1 unit $\mathbf{down}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |

# %% [markdown]
# ### Quad IV
#
# | # | Slope ($m$) | $\Delta x / \Delta y$ Target | P1 $(x_1, y_1)$ | P2 $(x_2, y_2)$ | $\Delta x$ | $\Delta y$ | $\frac{1}{m} = \frac{\Delta x}{\Delta y}$ | Interpretation of $\frac{1}{m}$ ($\Delta y=1$) |
# | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | 1 | $\mathbf{m = \infty}$ | $\frac{0}{\pm}$ | $(2, -3)$ | $(2, -1)$ | $0$ | $2$ | $\mathbf{0}$ | $\mathbf{0}$ units Right (Vertical Line) |
# | 2 | $\mathbf{m = 2}$ | $\frac{1}{2}$ | $(1, -3)$ | $(2, -1)$ | $1$ | $2$ | $\mathbf{0.5}$ | $\mathbf{0.5}$ units Right (Steep) |
# | 3 | $\mathbf{m = 1}$ | $\frac{1}{1}$ | $(1, -2)$ | $(2, -1)$ | $1$ | $1$ | $\mathbf{1}$ | $\mathbf{1}$ unit Right (Moderate) |
# | 4 | $\mathbf{m = 0.5}$ | $\frac{2}{1}$ | $(1, -2)$ | $(3, -1)$ | $2$ | $1$ | $\mathbf{2}$ | $\mathbf{2}$ units Right (Shallow) |
# | 5 | $\mathbf{m = 0}$ | $\frac{\pm}{0}$ | $(1, -2)$ | $(3, -2)$ | $2$ | $0$ | **$\infty$ (Undefined)** | Infinite Run (Horizontal Line) |
# | 6 | $\mathbf{m = -2}$ | $\frac{1}{-2}$ | $(3, -1)$ | $(4, -3)$ | $1$ | $-2$ | $\mathbf{-0.5}$ | For 1 unit $\mathbf{down}$, $\mathbf{0.5}$ units $\mathbf{right}$ (Steep Fall) |
# | 7 | $\mathbf{m = -1}$ | $\frac{1}{-1}$ | $(3, -1)$ | $(4, -2)$ | $1$ | $-1$ | $\mathbf{-1}$ | For 1 unit $\mathbf{down}$, $\mathbf{1}$ unit $\mathbf{right}$ (Moderate Fall) |
# | 8 | $\mathbf{m = -0.5}$ | $\frac{2}{-1}$ | $(3, -1)$ | $(5, -2)$ | $2$ | $-1$ | $\mathbf{-2}$ | For 1 unit $\mathbf{down}$, $\mathbf{2}$ units $\mathbf{right}$ (Shallow Fall) |
# | 9 | $\mathbf{m = \frac{1}{-3}}$ | $\frac{-3}{1}$ | $(4, -1)$ | $(1, 0)$ | $-3$ | $1$ | $\mathbf{-3}$ | For 1 unit $\mathbf{up}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |
# | 10 | $\mathbf{m = \frac{1}{3}}$ | $\frac{3}{1}$ | $(4, -1)$ | $(1, -2)$ | $-3$ | $-1$ | $\mathbf{3}$ | For 1 unit $\mathbf{down}$, $\mathbf{3}$ units $\mathbf{left}$ (Shallow) |

# %% [markdown]
# | Crossing | Quadrants $(x_1, y_1)$ to $(x_2, y_2)$ | Sample Points | $\Delta x$ (Run) | $\Delta y$ (Rise) | Calculation ($\frac{\Delta x}{\Delta y}$) | Inverse Slope ($\frac{1}{m}$) |
# | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | **I to II** | $(+, +)$ to $(-, +)$ | $(1, 2)$ to $(-3, 4)$ | $-3 - 1 = \mathbf{-4}$ | $4 - 2 = \mathbf{2}$ | $\frac{-4}{2}$ | $\mathbf{-2}$ |
# | **I to III** | $(+, +)$ to $(-, -)$ | $(2, 1)$ to $(-2, -1)$ | $-2 - 2 = \mathbf{-4}$ | $-1 - 1 = \mathbf{-2}$ | $\frac{-4}{-2}$ | $\mathbf{2}$ |
# | **I to IV** | $(+, +)$ to $(+, -)$ | $(3, 5)$ to $(4, -2)$ | $4 - 3 = \mathbf{1}$ | $-2 - 5 = \mathbf{-7}$ | $\frac{1}{-7}$ | $\mathbf{-\frac{1}{7}}$ |
# | **II to I** | $(-, +)$ to $(+, +)$ | $(-4, 1)$ to $(1, 3)$ | $1 - (-4) = \mathbf{5}$ | $3 - 1 = \mathbf{2}$ | $\frac{5}{2}$ | $\mathbf{2.5}$ |
# | **III to I** | $(-, -)$ to $(+, +)$ | $(-1, -3)$ to $(3, 1)$ | $3 - (-1) = \mathbf{4}$ | $1 - (-3) = \mathbf{4}$ | $\frac{4}{4}$ | $\mathbf{1}$ |
# | **IV to I** | $(+, -)$ to $(+, +)$ | $(5, -1)$ to $(2, 3)$ | $2 - 5 = \mathbf{-3}$ | $3 - (-1) = \mathbf{4}$ | $\frac{-3}{4}$ | $\mathbf{-\frac{3}{4}}$ |
# | **II to III** | $(-, +)$ to $(-, -)$ | $(-2, 5)$ to $(-5, -1)$ | $-5 - (-2) = \mathbf{-3}$ | $-1 - 5 = \mathbf{-6}$ | $\frac{-3}{-6}$ | $\mathbf{\frac{1}{2}}$ |
# | **II to IV** | $(-, +)$ to $(+, -)$ | $(-3, 2)$ to $(4, -4)$ | $4 - (-3) = \mathbf{7}$ | $-4 - 2 = \mathbf{-6}$ | $\frac{7}{-6}$ | $\mathbf{-\frac{7}{6}}$ |
# | **III to II** | $(-, -)$ to $(-, +)$ | $(-4, -2)$ to $(-1, 3)$ | $-1 - (-4) = \mathbf{3}$ | $3 - (-2) = \mathbf{5}$ | $\frac{3}{5}$ | $\mathbf{\frac{3}{5}}$ |
# | **IV to II** | $(+, -)$ to $(-, +)$ | $(1, -5)$ to $(-2, 2)$ | $-2 - 1 = \mathbf{-3}$ | $2 - (-5) = \mathbf{7}$ | $\frac{-3}{7}$ | $\mathbf{-\frac{3}{7}}$ |
# | **III to IV** | $(-, -)$ to $(+, -)$ | $(-5, -4)$ to $(1, -3)$ | $1 - (-5) = \mathbf{6}$ | $-3 - (-4) = \mathbf{1}$ | $\frac{6}{1}$ | $\mathbf{6}$ |
# | **IV to III** | $(+, -)$ to $(-, -)$ | $(3, -2)$ to $(-1, -4)$ | $-1 - 3 = \mathbf{-4}$ | $-4 - (-2) = \mathbf{-2}$ | $\frac{-4}{-2}$ | $\mathbf{2}$ |
